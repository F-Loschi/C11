# %% [markdown]
# # Exercícios Capítulo 5 Parte 2
# ## Nome: Felipe Silva Loschi
# ## Matrícula: 601

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##Exercício 1:

# %% [markdown]
# ###a)

# %%
df = pd.read_csv('/content/paises.csv', sep=';')
df
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %%
oceania = df['Country'][df['Region'].str.contains('OCEANIA')]
oceania
# Out:
# 3            American Samoa
# 11                Australia
# 47             Cook Islands
# 67                     Fiji
# 71         French Polynesia
# 83                     Guam
# 108                Kiribati
# 130        Marshall Islands
# 136    Micronesia, Fed. St.
# 144                   Nauru
# 148           New Caledonia
# 149             New Zealand
# 153      N. Mariana Islands
# 157                   Palau
# 159        Papua New Guinea
# 176                   Samoa
# 187         Solomon Islands
# 203                   Tonga
# 209                  Tuvalu
# 217                 Vanuatu
# 221       Wallis and Futuna
# Name: Country, dtype: object

# %% [markdown]
# b)

# %%
print(oceania.count())
# Out:
# 21

# %% [markdown]
# ##Exercício 2

# %%
df.loc[df['Population'].idxmax(), ['Country','Region']]
# Out:
# Country                           China
# Region     ASIA (EX. NEAR EAST)
# Name: 42, dtype: object

# %% [markdown]
# ##Exercício 3

# %%
df_por_regiao = df.groupby('Region')
df_por_regiao['Literacy (%)'].mean()
# Out:
# Region
# ASIA (EX. NEAR EAST)                   79.553571
# BALTICS                                99.733333
# C.W. OF IND. STATES                    98.725000
# EASTERN EUROPE                         72.816667
# LATIN AMER. & CARIB                    88.640000
# NEAR EAST                              69.581250
# NORTHERN AFRICA                        56.033333
# NORTHERN AMERICA                       78.200000
# OCEANIA                                71.914286
# SUB-SAHARAN AFRICA                     61.284314
# WESTERN EUROPE                         80.821429
# Name: Literacy (%), dtype: float64

# %% [markdown]
# ## Exercício 4

# %%
noCoast = df[df['Coastline (coast/area ratio)']== 0]
noCoast
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 4                 Andorra   WESTERN EUROPE                            71201
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 12                Austria   WESTERN EUROPE                          8192880
# 13             Azerbaijan                  C.W. OF IND. STATES      7961619
# 18                Belarus                  C.W. OF IND. STATES     10293011
# 23                 Bhutan         ASIA (EX. NEAR EAST)              2279723
# 24                Bolivia               LATIN AMER. & CARIB         8989046
# 26               Botswana   SUB-SAHARAN AFRICA                      1639833
# 31           Burkina Faso   SUB-SAHARAN AFRICA                     13902972
# 33                Burundi   SUB-SAHARAN AFRICA                      8090068
# ...

# %%
noCoast.to_csv('noCoast.csv')

# %% [markdown]
# ## Exercício 5

# %%
##Definindo a função

def humanitaryHelp(x):
  if(x<9):
    return 'Balanced'
  else:
    return 'Urgent'

# %%
HumanitarianHelp = df['Deathrate']
HumanitarianHelp = HumanitarianHelp.apply(humanitaryHelp)
HumanitarianHelp
# Out:
# 0        Urgent
# 1      Balanced
# 2      Balanced
# 3      Balanced
# 4      Balanced
#          ...
# 222    Balanced
# 223    Balanced
# 224    Balanced
# 225      Urgent
# 226      Urgent
# Name: Deathrate, Length: 227, dtype: object

# %%
df['Humanitarian Help'] = HumanitarianHelp
df
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...
